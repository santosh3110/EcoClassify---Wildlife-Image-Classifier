# %%
# !git clone https://github.com/santosh3110/EcoClassify---Wildlife-Image-Classifier.git
# %cd /content/EcoClassify---Wildlife-Image-Classifier
# Out:
# fatal: destination path 'EcoClassify---Wildlife-Image-Classifier' already exists and is not an empty directory.
# /content/EcoClassify---Wildlife-Image-Classifier

# %%
# !pip install -r requirements.txt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4b615c9b-6898-4222-ac6f-610c19095c3d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4b615c9b-6898-4222-ac6f-610c19095c3d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import sys

src_path = os.path.abspath(os.path.join(os.getcwd(), 'src'))
sys.path.append(src_path)
os.environ['PYTHONPATH'] = f"{src_path}:{os.environ.get('PYTHONPATH', '')}"

# %%
from dotenv import load_dotenv
load_dotenv(".env")
# Out:
# True

# %%
import os
os.environ["MLFLOW_TRACKING_USERNAME"] = os.getenv("MLFLOW_TRACKING_USERNAME")
os.environ["MLFLOW_TRACKING_PASSWORD"] = os.getenv("MLFLOW_TRACKING_PASSWORD")

# %%
from ecoclassify import logger
logger.info("✅ Module import working in Colab!")
# Out:
# [2025-08-05 14:07:59,115: INFO: ipython-input-1185842152: ✅ Module import working in Colab!]
# INFO:ecoclassifyLogger:✅ Module import working in Colab!

# %%
# !python main.py
# Out:
# [2025-08-05 14:08:00,525: INFO: data_ingestion: data_ingestion]
# [2025-08-05 14:08:12,245: INFO: main:
#
# >>>>> STARTING Data Ingestion Stage <<<<<]
# [2025-08-05 14:08:12,248: INFO: common: YAML file loaded: config/config.yaml]
# [2025-08-05 14:08:12,251: INFO: common: YAML file loaded: params.yaml]
# [2025-08-05 14:08:12,251: INFO: common: Created directory at: artifacts]
# [2025-08-05 14:08:12,251: INFO: common: Created directory at: artifacts/data_ingestion]
# [2025-08-05 14:08:12,252: INFO: data_ingestion: Downloading dataset...]
# [2025-08-05 14:08:51,089: INFO: data_ingestion: Dataset downloaded with following info:
# x-amz-id-2: V48pnfJxhZUU5+0lCtrQ/gMg88CFQRaCVsRG2TebsenYEV+vwO80AwDdQNQng8J8T8QAVhIFtVY=
# x-amz-request-id: 25H7K2E213KGRZ6W
# Date: Tue, 05 Aug 2025 14:08:13 GMT
# x-amz-replication-status: COMPLETED
# Last-Modified: Tue, 19 Apr 2022 17:27:21 GMT
# ETag: "70ff97ffa8d37095d4e05dfbeae72bb4-71"
# Cache-Control: max-age=604800
# x-amz-version-id: null
# ...
